# %%
# !pip install -q tensorflow==2.1.0
# Out:
#      |████████████████████████████████| 421.8MB 37kB/s
#      |████████████████████████████████| 3.9MB 47.7MB/s
#      |████████████████████████████████| 450kB 41.9MB/s
# ...

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('kc_house_data.csv')

# %%
# to check, how many null values per column
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.head()
# Out:
#            id        date     price  ...     long  sqft_living15  sqft_lot15
# 0  7129300520  10/13/2014  221900.0  ... -122.257           1340        5650
# 1  6414100192   12/9/2014  538000.0  ... -122.319           1690        7639
# 2  5631500400   2/25/2015  180000.0  ... -122.233           2720        8062
# 3  2487200875   12/9/2014  604000.0  ... -122.393           1360        5000
# 4  1954400510   2/18/2015  510000.0  ... -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
df.describe().transpose()
# Out:
#                  count          mean  ...           75%           max
# id             21597.0  4.580474e+09  ...  7.308900e+09  9.900000e+09
# price          21597.0  5.402966e+05  ...  6.450000e+05  7.700000e+06
# bedrooms       21597.0  3.373200e+00  ...  4.000000e+00  3.300000e+01
# bathrooms      21597.0  2.115826e+00  ...  2.500000e+00  8.000000e+00
# sqft_living    21597.0  2.080322e+03  ...  2.550000e+03  1.354000e+04
# sqft_lot       21597.0  1.509941e+04  ...  1.068500e+04  1.651359e+06
# floors         21597.0  1.494096e+00  ...  2.000000e+00  3.500000e+00
# waterfront     21597.0  7.547345e-03  ...  0.000000e+00  1.000000e+00
# view           21597.0  2.342918e-01  ...  0.000000e+00  4.000000e+00
# condition      21597.0  3.409825e+00  ...  4.000000e+00  5.000000e+00
# grade          21597.0  7.657915e+00  ...  8.000000e+00  1.300000e+01
# sqft_above     21597.0  1.788597e+03  ...  2.210000e+03  9.410000e+03
# ...

# %%
plt.figure(figsize=(10, 6))
sns.distplot(df['price'])

# %%
sns.countplot(df['bedrooms'])

# %%
df.corr()['price'].sort_values()
# Out:
# zipcode         -0.053402
# id              -0.016772
# long             0.022036
# condition        0.036056
# yr_built         0.053953
# sqft_lot15       0.082845
# sqft_lot         0.089876
# yr_renovated     0.126424
# floors           0.256804
# waterfront       0.266398
# lat              0.306692
# bedrooms         0.308787
# sqft_basement    0.323799
# view             0.397370
# bathrooms        0.525906
# sqft_living15    0.585241
# sqft_above       0.605368
# grade            0.667951
# sqft_living      0.701917
# price            1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x='price', y='sqft_living', data=df)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='bedrooms', y='price', data=df)

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='price', y='long', data=df)

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='price', y='lat', data=df)

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='long', y='lat', data=df, hue='price')

# %%
df.sort_values('price', ascending=False).head(20)
# Out:
#                id        date      price  ...     long  sqft_living15  sqft_lot15
# 7245   6762700020  10/13/2014  7700000.0  ... -122.323           3940        8800
# 3910   9808700762   6/11/2014  7060000.0  ... -122.214           3930       25449
# 9245   9208900037   9/19/2014  6890000.0  ... -122.240           4540       42730
# 4407   2470100110    8/4/2014  5570000.0  ... -122.233           3560       24345
# 1446   8907500070   4/13/2015  5350000.0  ... -122.220           4600       21750
# 1313   7558700030   4/13/2015  5300000.0  ... -122.210           4320       24619
# 1162   1247600105  10/20/2014  5110000.0  ... -122.211           3430       26788
# 8085   1924059029   6/17/2014  4670000.0  ... -122.210           3270       10454
# 2624   7738500731   8/15/2014  4500000.0  ... -122.280           3030       23408
# 8629   3835500195   6/18/2014  4490000.0  ... -122.219           3720       14592
# ...

# %%
len(df) * 0.01
# Out:
# 215.97

# %%
non_top_1_perc = df.sort_values('price', ascending=False).iloc[216:]

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='long', y='lat', data=non_top_1_perc, edgecolor=None, alpha=0.2, palette='RdYlGn', hue='price')

# %%
sns.boxplot(x='waterfront', y='price', data=df)

# %% [markdown]
# ## **Feature Engineering**

# %%
df = df.drop('id', axis=1)

# %%
# changing date from string to datatime object
df['date'] = pd.to_datetime(df['date'])

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
def year_extraction(date):
  return date.year

# %%
df['year'] = df['date'].apply(lambda date: date.year)

# %%
df['month'] = df['date'].apply(lambda date: date.month)

# %%
df.head()
# Out:
#         date     price  bedrooms  ...  sqft_lot15  year  month
# 0 2014-10-13  221900.0         3  ...        5650  2014     10
# 1 2014-12-09  538000.0         3  ...        7639  2014     12
# 2 2015-02-25  180000.0         2  ...        8062  2015      2
# 3 2014-12-09  604000.0         4  ...        5000  2014     12
# 4 2015-02-18  510000.0         3  ...        7503  2015      2
#
# [5 rows x 22 columns]

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='month', y='price', data=df)

# %%
df.groupby('month').mean()['price'].plot()

# %%
df.groupby('year').mean()['price'].plot()

# %%
df = df.drop('date', axis=1)

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year', 'month'],
#       dtype='object')

# %%
df.head()
# Out:
#       price  bedrooms  bathrooms  ...  sqft_lot15  year  month
# 0  221900.0         3       1.00  ...        5650  2014     10
# 1  538000.0         3       2.25  ...        7639  2014     12
# 2  180000.0         2       1.00  ...        8062  2015      2
# 3  604000.0         4       3.00  ...        5000  2014     12
# 4  510000.0         3       2.00  ...        7503  2015      2
#
# [5 rows x 21 columns]

# %%
df['zipcode'].value_counts()
# Out:
# 98103    602
# 98038    589
# 98115    583
# 98052    574
# 98117    553
#         ...
# 98102    104
# 98010    100
# 98024     80
# 98148     57
# 98039     50
# Name: zipcode, Length: 70, dtype: int64

# %%
df = df.drop('zipcode', axis=1)

# %%
df['sqft_basement'].value_counts()
# Out:
# 0       13110
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 792         1
# 2590        1
# 935         1
# 2390        1
# 248         1
# Name: sqft_basement, Length: 306, dtype: int64

# %% [markdown]
# ##**Building Model**

# %%
X = df.drop('price', axis=1).values
y = df['price'].values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test  = train_test_split(X, y, test_size=.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# to check, how many neurons are needed at first layer
X_train.shape
# Out:
# (15117, 19)

# %%
model = Sequential()

# %%
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))
model.add(Dense(19, activation='relu'))

model.add(Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
model.fit(x=X_train, y=y_train, validation_data=(X_test, y_test), batch_size=128, epochs=400)
# Out:
# Train on 15117 samples, validate on 6480 samples
# Epoch 1/400
# 15117/15117 [==============================] - 1s 42us/sample - loss: 430224915912.0820 - val_loss: 418826917245.7877
# Epoch 2/400
# 15117/15117 [==============================] - 0s 19us/sample - loss: 428030623466.5439 - val_loss: 411372074021.9259
# Epoch 3/400
# 15117/15117 [==============================] - 0s 18us/sample - loss: 399994083768.1635 - val_loss: 349945733747.0420
# Epoch 4/400
# 15117/15117 [==============================] - 0s 19us/sample - loss: 283123601891.1096 - val_loss: 184778199070.3408
# Epoch 5/400
# 15117/15117 [==============================] - 0s 18us/sample - loss: 132001717595.7007 - val_loss: 96833390779.1012
# Epoch 6/400
# 15117/15117 [==============================] - 0s 19us/sample - loss: 97922863968.6118 - val_loss: 93516591457.9753
# Epoch 7/400
# 15117/15117 [==============================] - 0s 18us/sample - loss: 95605534062.1256 - val_loss: 91449622426.8642
# Epoch 8/400
# ...

# %%
# to get the history of losses during training data
pd.DataFrame(model.history.history)
# Out:
#              loss      val_loss
# 0    4.302249e+11  4.188269e+11
# 1    4.280306e+11  4.113721e+11
# 2    3.999941e+11  3.499457e+11
# 3    2.831236e+11  1.847782e+11
# 4    1.320017e+11  9.683339e+10
# ..            ...           ...
# 395  3.043223e+10  2.812298e+10
# 396  3.048278e+10  2.806318e+10
# 397  3.045235e+10  2.810175e+10
# 398  3.042831e+10  2.818002e+10
# 399  3.040045e+10  2.805528e+10
#
# [400 rows x 2 columns]

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score

# %%
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array([[407692.28],
#        [601528.1 ],
#        [553127.6 ],
#        ...,
#        [373914.12],
#        [562462.9 ],
#        [695589.6 ]], dtype=float32)

# %%
# mean squred error gives the squares of value, therefore, it is better to take 
# mean root error. To get this, take square root of it. 
np.sqrt(mean_squared_error(y_test, predictions))
# Out:
# 167497.0987032855

# %%
mean_absolute_error(y_test, predictions)
# Out:
# 103958.3550564236

# %%
df['price'].describe()
# Out:
# count    2.159700e+04
# mean     5.402966e+05
# std      3.673681e+05
# min      7.800000e+04
# 25%      3.220000e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      7.700000e+06
# Name: price, dtype: float64

# %%
5.402966e+05
# Out:
# 540296.6

# %%
explained_variance_score(y_test, predictions)
# Out:
# 0.7885991163348541

# %%
plt.figure(figsize=(12, 6))
plt.scatter(y_test, predictions)
plt.plot(y_test, y_test, 'r')

# %%
df
# Out:
#           price  bedrooms  bathrooms  ...  sqft_lot15  year  month
# 0      221900.0         3       1.00  ...        5650  2014     10
# 1      538000.0         3       2.25  ...        7639  2014     12
# 2      180000.0         2       1.00  ...        8062  2015      2
# 3      604000.0         4       3.00  ...        5000  2014     12
# 4      510000.0         3       2.00  ...        7503  2015      2
# ...         ...       ...        ...  ...         ...   ...    ...
# 21592  360000.0         3       2.50  ...        1509  2014      5
# 21593  400000.0         4       2.50  ...        7200  2015      2
# 21594  402101.0         2       0.75  ...        2007  2014      6
# 21595  400000.0         3       2.50  ...        1287  2015      1
# 21596  325000.0         2       0.75  ...        1357  2014     10
#
# [21597 rows x 20 columns]

# %%
single_house = df.drop('price', axis=1).iloc[0]

# %%
single_house.values.reshape(-1, 19)
# Out:
# array([[ 3.00000e+00,  1.00000e+00,  1.18000e+03,  5.65000e+03,
#          1.00000e+00,  0.00000e+00,  0.00000e+00,  3.00000e+00,
#          7.00000e+00,  1.18000e+03,  0.00000e+00,  1.95500e+03,
#          0.00000e+00,  4.75112e+01, -1.22257e+02,  1.34000e+03,
#          5.65000e+03,  2.01400e+03,  1.00000e+01]])

# %%
scaler.transform(single_house.values.reshape(-1, 19))
# Out:
# array([[0.2       , 0.08      , 0.08376422, 0.00310751, 0.        ,
#         0.        , 0.        , 0.5       , 0.4       , 0.10785619,
#         0.        , 0.47826087, 0.        , 0.57149751, 0.21760797,
#         0.16193426, 0.00582059, 0.        , 0.81818182]])

# %%
single_house = scaler.transform(single_house.values.reshape(-1, 19))

# %%
model.predict(single_house)
# Out:
# array([[279052.12]], dtype=float32)

# %%
df.head(1)
# Out:
#       price  bedrooms  bathrooms  ...  sqft_lot15  year  month
# 0  221900.0         3        1.0  ...        5650  2014     10
#
# [1 rows x 20 columns]

# %%
279052.12 -221900.0
# Out:
# 57152.119999999995
